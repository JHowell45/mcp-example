# %%
from pathlib import Path
from pandas import DataFrame, read_csv

DATASET_PATH: Path = Path("../datasets").resolve()
print(f"{DATASET_PATH=}")
# Out:
# DATASET_PATH=PosixPath('/home/jacob/Code/projects/mcp-example/example-api/datasets')

# %%
df: DataFrame = read_csv(DATASET_PATH / "movies_metadata.csv")
print(df.columns)
df
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')
# /tmp/ipykernel_24863/1760627803.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df: DataFrame = read_csv(DATASET_PATH / "movies_metadata.csv")
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# ...

# %%
df_cp = df.copy()
df_cp.drop(columns=["id", "adult", "poster_path", "video", "homepage", "original_language", "original_title"], inplace=True)
print(df_cp.columns)
df_cp
# Out:
# Index(['belongs_to_collection', 'budget', 'genres', 'imdb_id', 'overview',
#        'popularity', 'production_companies', 'production_countries',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
#        'tagline', 'title', 'vote_average', 'vote_count'],
#       dtype='object')
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45461                                                NaN         0
# 45462                                                NaN         0
# ...

# %%
for row in df_cp.spoken_languages:
    print(row)
# Out:
# [{'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'fr', 'name': 'Français'}]
# [{'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'es', 'name': 'Español'}]
# [{'iso_639_1': 'fr', 'name': 'Français'}, {'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'de', 'name': 'Deutsch'}]
# [{'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'ru', 'name': 'Pусский'}, {'iso_639_1': 'es', 'name': 'Español'}]
# [{'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'de', 'name': 'Deutsch'}]
# [{'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}]
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'la', 'name': 'Latin'}]
# ...
